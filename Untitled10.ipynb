# %% [markdown]
# <a href="https://colab.research.google.com/github/777sapp/Nurul-Safirah-/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
 dataset = '/content/department_store_dataset.csv.zip'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#                    Seller   Department  Revenue  Revenue Goal  Margin  \
# 0      Letícia Nascimento  Eletrônicos  6139.41       1857.66    0.14
# 1               Ana Sousa  Eletrônicos  7044.96       5236.01    0.30
# 2         Gustavo Martins  Eletrônicos  4109.85       1882.47    0.14
# 3          Beatriz Santos    Vestuário   315.30       2069.08    0.20
# 4             Camila Lima    Vestuário  1672.33       3587.07    0.24
# ...                   ...          ...      ...           ...     ...
# 41624     Camila Carvalho         Casa  1515.27       3472.65    0.22
# 41625       Diego Cardoso    Vestuário  1988.60       1860.28    0.15
# 41626        Jorge Santos    Brinquedo  2408.98       1392.15    0.29
# 41627       Raphael Silva    Papelaria  1414.54        298.84    0.34
# 41628       Caroline Reis    Papelaria  1495.06        850.31    0.34
#
#        Margin Goal        Date  Sales Quantity  Customers
# 0             0.18  2017-01-01              50        213
# ...

# %%
data.head()
# Out:
#                Seller   Department  Revenue  Revenue Goal  Margin  \
# 0  Letícia Nascimento  Eletrônicos  6139.41       1857.66    0.14
# 1           Ana Sousa  Eletrônicos  7044.96       5236.01    0.30
# 2     Gustavo Martins  Eletrônicos  4109.85       1882.47    0.14
# 3      Beatriz Santos    Vestuário   315.30       2069.08    0.20
# 4         Camila Lima    Vestuário  1672.33       3587.07    0.24
#
#    Margin Goal        Date  Sales Quantity  Customers
# 0         0.18  2017-01-01              50        213
# 1         0.17  2017-01-01              52        256
# 2         0.20  2017-01-01              33        189
# 3         0.17  2017-01-01               2          6
# 4         0.14  2017-01-01              12         50

# %%
print(data.dtypes)
# Out:
# Seller             object
# Department         object
# Revenue           float64
# Revenue Goal      float64
# Margin            float64
# Margin Goal       float64
# Date               object
# Sales Quantity      int64
# Customers           int64
# dtype: object

# %%
datanoid = data.drop(data.columns[4],axis=1)

# %%
datanoid
# Out:
#                    Seller   Department  Revenue  Revenue Goal  Margin Goal  \
# 0      Letícia Nascimento  Eletrônicos  6139.41       1857.66         0.18
# 1               Ana Sousa  Eletrônicos  7044.96       5236.01         0.17
# 2         Gustavo Martins  Eletrônicos  4109.85       1882.47         0.20
# 3          Beatriz Santos    Vestuário   315.30       2069.08         0.17
# 4             Camila Lima    Vestuário  1672.33       3587.07         0.14
# ...                   ...          ...      ...           ...          ...
# 41624     Camila Carvalho         Casa  1515.27       3472.65         0.28
# 41625       Diego Cardoso    Vestuário  1988.60       1860.28         0.16
# 41626        Jorge Santos    Brinquedo  2408.98       1392.15         0.23
# 41627       Raphael Silva    Papelaria  1414.54        298.84         0.49
# 41628       Caroline Reis    Papelaria  1495.06        850.31         0.43
#
#              Date  Sales Quantity  Customers
# ...

# %%
data.describe()
# Out:
#             Revenue  Revenue Goal        Margin   Margin Goal  Sales Quantity  \
# count  41629.000000  41629.000000  41629.000000  41629.000000    41629.000000
# mean    4304.522655   4458.557065      0.279164      0.291039       33.368950
# std     4158.522015   3258.360518      0.150589      0.113495       30.885202
# min        0.000000    241.010000      0.028000      0.140000        0.000000
# 25%     1239.000000   1980.560000      0.170000      0.200000       10.000000
# 50%     2934.710000   3472.410000      0.250000      0.260000       24.000000
# 75%     6110.730000   6269.260000      0.350000      0.360000       47.000000
# max    22471.310000  16987.970000      0.800000      0.600000      185.000000
#
#           Customers
# count  41629.000000
# mean     126.298878
# std      123.439971
# min        0.000000
# 25%       36.000000
# 50%       89.000000
# 75%      179.000000
# max      859.000000

# %%
 data.loc[:,"Revenue":].corr()
# Out:
# <ipython-input-17-d6928ff7bafb>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Revenue":].corr()
#                  Revenue  Revenue Goal    Margin  Margin Goal  Sales Quantity  \
# Revenue         1.000000      0.431344 -0.121180    -0.219683        0.933088
# Revenue Goal    0.431344      1.000000 -0.215464    -0.290161        0.295166
# Margin         -0.121180     -0.215464  1.000000     0.647845       -0.128032
# Margin Goal    -0.219683     -0.290161  0.647845     1.000000       -0.234797
# Sales Quantity  0.933088      0.295166 -0.128032    -0.234797        1.000000
# Customers       0.674222      0.095918 -0.122928    -0.224238        0.828683
#
#                 Customers
# Revenue          0.674222
# Revenue Goal     0.095918
# Margin          -0.122928
# Margin Goal     -0.224238
# ...

# %%
# Revenue vs Revenue Goal

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Revenue', y='Revenue Goal', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-7ee4e059-a50f-4b33-9a15-9e6ea08cee3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ee4e059-a50f-4b33-9a15-9e6ea08cee3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "department store"
# Out:
# ...
# ref                                                            title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# raphaelpuziol/department-store-sales-dataset                   Department Store Sales Dataset                      714KB  2023-09-20 21:35:54           2104         44  1.0
# manjeetsingh/retaildataset                                     Retail Data Analytics                                 3MB  2017-09-01 03:03:57          75734        981  0.8235294
# olistbr/brazilian-ecommerce                                    Brazilian E-Commerce Public Dataset by Olist         43MB  2021-10-01 19:08:27         230353       3056  1.0
# ...

# %%
# !kaggle datasets download raphaelpuziol/department-store-sales-dataset
# Out:
# ...
# 100% 714k/714k [00:00<00:00, 1.16MB/s]
# 100% 714k/714k [00:00<00:00, 1.16MB/s]

# %%
# !unzip /content/department-store-sales-dataset.zip
# Out:
# Archive:  /content/department-store-sales-dataset.zip
#   inflating: department_store_dataset.csv

# %%
pd.read_csv('/content/department_store_dataset.csv')
# Out:
#                    Seller   Department  Revenue  Revenue Goal  Margin  \
# 0      Letícia Nascimento  Eletrônicos  6139.41       1857.66    0.14
# 1               Ana Sousa  Eletrônicos  7044.96       5236.01    0.30
# 2         Gustavo Martins  Eletrônicos  4109.85       1882.47    0.14
# 3          Beatriz Santos    Vestuário   315.30       2069.08    0.20
# 4             Camila Lima    Vestuário  1672.33       3587.07    0.24
# ...                   ...          ...      ...           ...     ...
# 41624     Camila Carvalho         Casa  1515.27       3472.65    0.22
# 41625       Diego Cardoso    Vestuário  1988.60       1860.28    0.15
# 41626        Jorge Santos    Brinquedo  2408.98       1392.15    0.29
# 41627       Raphael Silva    Papelaria  1414.54        298.84    0.34
# 41628       Caroline Reis    Papelaria  1495.06        850.31    0.34
#
#        Margin Goal        Date  Sales Quantity  Customers
# 0             0.18  2017-01-01              50        213
# ...

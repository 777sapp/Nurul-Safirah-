# %% [markdown]
# <a href="https://colab.research.google.com/github/777sapp/Nurul-Safirah-/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = '/content/Jumlah Penduduk Berumur 15 Tahun Keatas Menurut Jenis Kegiatan Selama Seminggu yang Lalu dan Jenis Kelamin, 2022.csv'
data = pd.read_csv(dataset)
data
# Out:
#                                       Kegiatan Utama  \
# 0              I. Angkatan Kerja/Economically Active
# 1                                 1. Bekerja/Working
# 2               2. Pengangguran Terbuka/Unemployment
# 3   II. Bukan Angkatan Kerja/Not Economically Active
# 4                        1. Sekolah/Attending School
# 5              2. Mengurus Rumah tangga/Housekeeping
# 6                                  3. Lainnya/Others
# 7                                       Jumlah/Total
# 8                                                NaN
# 9                                            Catatan
# 10                                                 -
#
#     Penduduk 15 tahun keatas - Laki-Laki  \
# 0                             87762583.0
# 1                             82553960.0
# 2                              5208623.0
# 3                             16873668.0
# 4                              7548454.0
# 5                              3621185.0
# ...

# %%
Kegiatan_Utama = ('Bekerja/Working', 'Pengangguran Terbuk', 'Sekolah', 'Mengurus Rumah Tangga', 'Lainnya')
Penduduk_15_tahun_keatas = (135296713, 8425931, 15609539, 41249965, 883823 )
colors = ('#F0FFF0','#FFB6C1','#AFEEEE','#FFFACD','#FFDEAD')
explode = (0,0,0,0,0)

plt.title('Penduduk 15 Tahun Keaatas')
plt. pie(
    votes,
    labels=Kegiatan_Utama,
    autopct='%1.1f%%',
    colors=colors,
    explode=explode,
    shadow=True,
    textprops={'fontsize': 8}
    )
plt.show()

# %% [markdown]
# Jadi, dari visualisasi data pie chart diatas. label Bekerja/Working memiliki persentase terbanyak. Jadi data tersebut menunjukkan bahwa Penduduk 15 tahun keaatas banyak yang telah bekerja
